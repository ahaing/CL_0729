# %%
#標準寫法
import matplotlib.pyplot as plt

# 1.製作figure
fig = plt.figure()

# 2.在1.的figure上製作一個axes
ax_1 = fig.add_subplot(1, 1, 1)

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y)

# 4.顯示圖
# plt.show()

#=========================================
fig = plt.figure()
ax_1 = fig.add_subplot(1,3,1)
ax_1.set_title("axes1")

ax_2 = fig.add_subplot(1,3,2)
ax_2.set_title("axes2")

ax_3 = fig.add_subplot(1,3,3)
ax_3.set_title("axes3")

#=========================================
student1 = {'CH':87, 'EN':90, 'MA':100, 'SC':200}
student2 = {'CH':100, 'EN':108, 'MA':100,'SC':108 }
student1.keys()
subjects = list(student1.keys())
subjects

value1=list(student1.values())
value2=list(student2.values())

#=========================================
figure = plt.figure(figsize=(8.0,5.0))
ax = figure.add_subplot()
ax.plot(subjects, value1)
ax.plot(subjects, value2, 'r',linestyle='dashed') # set_linestyle(ls) # ':' or 'dotted'=>' r:'
ax.set_title("student 1 & 2 comparison")
plt.show() #google matplotlib.axes.subplot(?)
# matplotlib.axes.Axes.plot

#=========================================
#codespace 要安裝中文字型
#命令列:sudo apt-get install -y fonts-wqy-zenhei
#字型位置:/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc
#=========================================
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
font1=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=12)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':90, 'english':75, 'math':98, 'history':65, 'discover':75}

subjects =list(student1.keys())
value1 =list(student1.values())
value2 = list(student2.values())

fig = plt.figure(figsize=(8,5), dpi=250, facecolor="#cccccc")
ax = fig.add_subplot(1,1,1)
ax.set_title("學生1和學生2分數比較表",fontproperties=font)
plt.show()

#=========================================
